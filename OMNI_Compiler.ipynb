# %% [markdown]
# ## This is developed by Tesfay and guided by his supervisors from NASA and UNIVAP(Brazil)
#
# ### This is an interactive python code to download and to visualize any high resolution OMNIWEB data
# #### This code is very attractive and encrypted to prevent unnecessary making busy for OMNIWEB sites, therefore feel free to reach us via our linkedin accountanad our E-mail:   tesfayphysics@gmail.com

# %% [markdown]
# ![My_Logo1.PNG](attachment:My_Logo1.PNG)

# %% [markdown]
# # GOOD-LUCK

# %%
# %run TT_NAT_Dec11_OMNI_Downloading_decr1.py

# %%
# %run TT_NAT_Dec11_OMNI_Plotting_decr1.py
csv_file = "Selective_omni_data_2024050900_2024051223.txt"  
column_names = ['YYYY', 'DOY', 'HR', 'MN', 'IMF', 'Bx', 'By', 'Bz', 'bzGSM', 'V[Km/s]', 'Dens', 'Temp', 'AE', 'SYM-H']
df = interactive_subplot(csv_file, column_names=column_names, skip_header_lines=18, skip_footer_lines=15)
